# %%
x = [23,39,42,58,64,75,79,82,91,97]
y = [13,15,27,38,46,51,54,69,85,99]

# %%
type (x), type (y)
# Out:
# (numpy.ndarray, list)

# %%
import matplotlib.pyplot as plt

# %%
plt.plot (x, y,'o')
plt.title ("Grafico de numeros aleatorios")
plt.xlabel("aleatorios x")
plt.ylabel ("aleatorios y")
plt.show ()

# %%
np.linspace (5,50,100)
# Out:
# array([ 5.        ,  5.45454545,  5.90909091,  6.36363636,  6.81818182,
#         7.27272727,  7.72727273,  8.18181818,  8.63636364,  9.09090909,
#         9.54545455, 10.        , 10.45454545, 10.90909091, 11.36363636,
#        11.81818182, 12.27272727, 12.72727273, 13.18181818, 13.63636364,
#        14.09090909, 14.54545455, 15.        , 15.45454545, 15.90909091,
#        16.36363636, 16.81818182, 17.27272727, 17.72727273, 18.18181818,
#        18.63636364, 19.09090909, 19.54545455, 20.        , 20.45454545,
#        20.90909091, 21.36363636, 21.81818182, 22.27272727, 22.72727273,
#        23.18181818, 23.63636364, 24.09090909, 24.54545455, 25.        ,
#        25.45454545, 25.90909091, 26.36363636, 26.81818182, 27.27272727,
#        27.72727273, 28.18181818, 28.63636364, 29.09090909, 29.54545455,
#        30.        , 30.45454545, 30.90909091, 31.36363636, 31.81818182,
#        32.27272727, 32.72727273, 33.18181818, 33.63636364, 34.09090909,
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import math
import scipy

# %%
def func (x):
    return np.cos(x)

# %%
x = np.linspace(10, 2*np.cos(45), 100)
y = func(x)

# %%
x
# Out:
# array([10.        ,  9.90960246,  9.81920493,  9.72880739,  9.63840986,
#         9.54801232,  9.45761479,  9.36721725,  9.27681972,  9.18642218,
#         9.09602464,  9.00562711,  8.91522957,  8.82483204,  8.7344345 ,
#         8.64403697,  8.55363943,  8.4632419 ,  8.37284436,  8.28244682,
#         8.19204929,  8.10165175,  8.01125422,  7.92085668,  7.83045915,
#         7.74006161,  7.64966407,  7.55926654,  7.468869  ,  7.37847147,
#         7.28807393,  7.1976764 ,  7.10727886,  7.01688133,  6.92648379,
#         6.83608625,  6.74568872,  6.65529118,  6.56489365,  6.47449611,
#         6.38409858,  6.29370104,  6.20330351,  6.11290597,  6.02250843,
#         5.9321109 ,  5.84171336,  5.75131583,  5.66091829,  5.57052076,
#         5.48012322,  5.38972569,  5.29932815,  5.20893061,  5.11853308,
#         5.02813554,  4.93773801,  4.84734047,  4.75694294,  4.6665454 ,
#         4.57614787,  4.48575033,  4.39535279,  4.30495526,  4.21455772,
# ...

# %%
with plt.xkcd():
    plt.figure(figsize=(8,6))
    plt.plot(x, y)
    plt.title(r"Gráfico função $cos(45)$ de tras p frente")
    plt.xlabel("x")
    plt.ylabel("y")
    plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data_file.txt')

# %%
df
# Out:
#           x             y
# 0     0.200  5.407452e+07
# 1     0.205  5.533155e+07
# 2     0.210  5.655147e+07
# 3     0.215  5.745155e+07
# 4     0.220  5.865122e+07
# ...     ...           ...
# 1005  7.460  5.295653e+01
# 1006  7.470  4.860971e+01
# 1007  7.480  5.308345e+01
# 1008  7.490  4.783996e+01
# 1009  7.500  4.899393e+01
#
# [1010 rows x 2 columns]

# %%
plt.semilogy (df['x'],df['y'],'o', c='xkcd:pink')
plt.title ("Grafico de dados")
plt.xlabel("x")
plt.ylabel ("y")
plt.show ()

# %%
import random as rd #[0,1)

# %%
def funcao (x):
    return np.sin(x)

# %%
funcao = lambda x: np.sin(x)

# %%
x = np.linspace (0,2*np.pi,100)
num_aleatorio = []
y = []

# %%
for i in range(len(x)):
    n_aleatorio = rd.random() * 0.4 #numeros menores que 0.4
    num_aleatorio.append(n_aleatorio) #append = adicionar numeros aleatorios novo na lista
    #matriz de 100 numeros aleatorios menor que 0.4

# %%
for i in range(len(x)):
    k = rd.randint (0,1)#limite inferior e superior
    if (k == 0):
        y.append(np.sin(x2[i]) + num_aleatorio[i])
        #soma ao valor da funcao
    else:
        y.append(np.sin(x[i]) - num_aleatorio[i])
        #subtrair numero aleatorio ao valor da funcao

# %%
plt.plot(x,y, 'o', c = 'pink')
plt.plot (x, np.sin (x), c = 'purple')
plt.show()
